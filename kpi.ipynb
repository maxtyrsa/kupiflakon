# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
sns.set_theme(
rc={'figure.figsize':(12,8)},
style="whitegrid")
import numpy as np

# %%
url = '/content/drive/MyDrive/Аналитика данных/sales_1.03.2024.csv'

# %%
sales = pd.read_csv(url, sep=';', parse_dates=['date'])
sales['date'] = pd.to_datetime(sales['date'], unit='ms')
sales["year_month"] = sales["date"].dt.to_period("M")

# %%
kf = sales.query("branch == 'Купи Флакон'")
mp = sales.query("branch == 'Маркетплейс'")

# %%
sum_kf_januar = januar_kf_count.count_orders_kf.sum()
sum_mp_januar = januar_mp_count.count_orders_mp.sum()
sum_kf_february = february_kf_count.count_orders_kf.sum()
sum_mp_february = february_mp_count.count_orders_mp.sum()

# %% [markdown]
# Январь 2024

# %%
januar_kf = kf[kf['year_month'] == '2024-01']
januar_mp = mp[mp['year_month'] == '2024-01']
januar_kf_count = januar_kf.groupby('date', as_index=False).agg({"place": "count"}).rename(columns={"place": "count_orders_kf"})
januar_mp_count = yanuar_mp.groupby('date', as_index=False).agg({"place": "sum"}).rename(columns={"place": "count_orders_mp"})

# %%
januar_kf = januar_kf.groupby('t_c', as_index=False).agg({"place": "count"}).rename(columns={"place": "counts"})
januar_kf['percent'] = round((januar_kf['counts'] /
                 januar_kf['counts'].sum()) * 100, 2)
januar_mp = januar_mp.groupby('t_c', as_index=False).agg({"place": "sum"}).rename(columns={"place": "counts"})
januar_mp['percent'] = round((januar_mp['counts'] /
                 januar_mp['counts'].sum()) * 100, 2)

# %%
januar_mp = januar_mp.sort_values('percent', ascending=False)
januar_kf = januar_kf.sort_values('percent', ascending=False)

# %%
sns.barplot(data=januar_kf_count, x='count_orders_kf', y='date')
print('''Заказы Купи Флакон Январь 2024
Количество заказов:''', sum_kf_januar)
print(januar_kf)
# Out:
# Заказы Купи Флакон Январь 2024
# Количество заказов: 204
#              t_c  counts  percent
# 5      Самовывоз      61    29.90
# 6           Сдек      47    23.04
# 1            DPD      39    19.12
# 0       Boxberry      28    13.73
# 4   Почта России      16     7.84
# 3            ПЭК       7     3.43
# 2  Деловые линии       6     2.94

# %%
sns.barplot(data=januar_mp_count, x='count_orders_mp', y='date')
print('''Заказы Маркетплейс Январь 2024
Количество заказов:''', sum_mp_januar)
print(januar_mp)
# Out:
# Заказы Маркетплейс Январь 2024
# Количество заказов: 131
#                 t_c  counts  percent
# 0       Wildberries      91    69.47
# 1              Озон      31    23.66
# 2     Яндекс Маркет       6     4.58
# 3  Ярмарка мастеров       3     2.29

# %%
all_orders_kf_mp_januar = pd.concat([januar_mp, januar_kf])
print('Количество заказов КФ и МП за Январь 2024:', all_orders_kf_mp_januar.counts.sum(), 'шт.')
print(all_orders_kf_mp_januar.sort_values('percent', ascending=False))
# Out:
# Количество заказов КФ и МП за Январь 2024: 335 шт.
#                 t_c  counts  percent
# 0       Wildberries      91    69.47
# 5         Самовывоз      61    29.90
# 1              Озон      31    23.66
# 6              Сдек      47    23.04
# 1               DPD      39    19.12
# 0          Boxberry      28    13.73
# 4      Почта России      16     7.84
# 2     Яндекс Маркет       6     4.58
# 3               ПЭК       7     3.43
# 2     Деловые линии       6     2.94
# 3  Ярмарка мастеров       3     2.29

# %%
ax = sns.barplot(all_orders_kf_mp_januar, x="percent", y="t_c", estimator="sum")
ax.bar_label(ax.containers[0], fontsize=10);
print('Процент заказов Январь 2024')
# Out:
# Процент заказов Январь 2024

# %%
ax = sns.barplot(all_orders_kf_mp_januar, x="counts", y="t_c", estimator="sum")
ax.bar_label(ax.containers[0], fontsize=10);
print('Количество заказов Январь 2024')
# Out:
# Количество заказов Январь 2024

# %% [markdown]
# Февраль 2024

# %%
february_kf = kf[kf['year_month'] == '2024-02']
february_mp = mp[mp['year_month'] == '2024-02']
february_kf_count = february_kf.groupby('date', as_index=False).agg({"place": "count"}).rename(columns={"place": "count_orders_kf"})
february_mp_count = february_mp.groupby('date', as_index=False).agg({"place": "sum"}).rename(columns={"place": "count_orders_mp"})

# %%
february_kf = february_kf.groupby('t_c', as_index=False).agg({"place": "count"}).rename(columns={"place": "counts"})
february_kf['percent'] = round((february_kf['counts'] /
                 february_kf['counts'].sum()) * 100, 2)
february_mp = february_mp.groupby('t_c', as_index=False).agg({"place": "sum"}).rename(columns={"place": "counts"})
february_mp['percent'] = round((february_mp['counts'] /
                 february_mp['counts'].sum()) * 100, 2)

# %%
february_mp = february_mp.sort_values('percent', ascending=False)
february_kf = february_kf.sort_values('percent', ascending=False)

# %%
sns.barplot(data=february_kf_count, x='count_orders_kf', y='date', label='Good KPI: + 23.39 %')
print('''Заказы Купи Флакон Февраль 2024
Количество заказов:''', sum_kf_february)
print(february_kf)
P = sum_kf_february
N = sum_kf_yanuar
B = 80
kpi = round((P-B)/(N-B)*100, 2)
if kpi > 100:
    print("Good KPI: +", kpi-100, "%")
else:
    print("Bad KPI:", kpi-100, "%")
# Out:
# Заказы Купи Флакон Февраль 2024
# Количество заказов: 233
#              t_c  counts  percent
# 6           Сдек      97    41.81
# 5      Самовывоз      57    24.57
# 0       Boxberry      30    12.93
# 1            DPD      28    12.07
# 4   Почта России      14     6.03
# 2  Деловые линии       3     1.29
# 3            ПЭК       3     1.29
# Good KPI: + 23.39 %

# %%
sns.barplot(data=february_mp_count, x='count_orders_mp', y='date', label='Good KPI: + 275.57 %')
print('''Заказы Маркетплейс Февраль 2024
Количество заказов:''', sum_mp_february)
print(february_mp)
P = sum_mp_february
N = sum_mp_yanuar
B = 0
kpi = round((P-B)/(N-B)*100, 2)
if kpi > 100:
    print("Good KPI: +", kpi-100, "%")
else:
    print("Bad KPI:", kpi-100, "%")
# Out:
# Заказы Маркетплейс Февраль 2024
# Количество заказов: 492
#                 t_c  counts  percent
# 2              Озон     363    73.78
# 0       Wildberries      80    16.26
# 3     Яндекс Маркет      46     9.35
# 4  Ярмарка мастеров       2     0.41
# 1        МегаМаркет       1     0.20
# Good KPI: + 275.57 %

# %%
mp_orders = februar_mp.groupby('t_c', as_index=False).agg({"place": "sum"}).rename(columns={"place": "counts"})
mp_orders['percent'] = round((mp_orders['counts'] /
                 mp_orders['counts'].sum()) * 100, 2)
kf_orders = februar_kf.groupby('t_c', as_index=False).agg({"place": "count"}).rename(columns={"place": "counts"})
kf_orders['percent'] = round((kf_orders['counts'] /
                 kf_orders['counts'].sum()) * 100, 2)
all_orders_kf_mp = pd.concat([mp_orders, kf_orders])
print('Количество заказов КФ и МП за Февраль 2024:', all_orders_kf_mp.counts.sum(), 'шт.')
print(all_orders_kf_mp.sort_values('percent', ascending=False))
# Out:
# Количество заказов КФ и МП за Февраль 2024: 724 шт.
#                 t_c  counts  percent
# 2              Озон     363    73.78
# 6              Сдек      97    41.81
# 5         Самовывоз      57    24.57
# 0       Wildberries      80    16.26
# 0          Boxberry      30    12.93
# 1               DPD      28    12.07
# 3     Яндекс Маркет      46     9.35
# 4      Почта России      14     6.03
# 2     Деловые линии       3     1.29
# 3               ПЭК       3     1.29
# 4  Ярмарка мастеров       2     0.41
# 1        МегаМаркет       1     0.20

# %%
ax = sns.barplot(all_orders_kf_mp, x="percent", y="t_c", estimator="sum")
ax.bar_label(ax.containers[0], fontsize=10);
print('Процент заказов Февраль 2024')
# Out:
# Процент заказов Февраль 2024

# %%
P = 724
N = 335
B = 80
kpi = round((P-B)/(N-B)*100, 2)
if kpi > 100:
    print("Good KPI: +", kpi-100, "%")
else:
    print("Bad KPI:", kpi-100, "%")
print('KPI Купи Флакон и Маркетплейс')
# Out:
# Good KPI: + 152.55 %
# KPI Купи Флакон и Маркетплейс

# %% [markdown]
# A/B test count orders KF

# %%
a_b_test = sales[sales['branch'] == 'Купи Флакон']

# %%
a_b_test = a_b_test.groupby('date', as_index=False).agg({"place": "count"})

# %%
a_b_test = a_b_test.place

# %%
a_b_test.mean()
# Out:
# 11.605263157894736

# %%
a_b_test.std()
# Out:
# 4.168994134205325

# %%
a_b_test.var()
# Out:
# 17.380512091038405

# %%
mu = 11.605263157894736
sigma = 4.168994134205325

# %%
a_b = np.random.normal(mu, sigma, 10000)

# %%
simple = 21

# %%
list = []
n = 1000

# %%
simple_mean = np.random.choice(a_b, simple, False)

# %%
for i in range(n):
    simple_mean = np.random.choice(a_b, simple, False)
    list.append(simple_mean.mean())

# %%
sns.distplot(list)
# Out:
# <ipython-input-111-6ef9e2752173>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(list)
# <Axes: ylabel='Density'>

# %%
a_b.mean()
# Out:
# 11.595546114919618

# %%
a_b.std()
# Out:
# 4.155735266206403

# %%
se = a_b.std()/a_b.mean()**0.5

# %%
a_b.mean() + 1.96 * se
# Out:
# 13.987530506681907

# %%
a_b.mean() - 1.96 * se
# Out:
# 9.203561723157328
